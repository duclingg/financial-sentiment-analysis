# %% [markdown]
# # Sentiment Analysis
#
# From the data that we preprocessed through cleaning, then linguistic processing; we are now able to gather the sentiment of the news articles.
#
# The sentiment scores returned by `NLTK's VADER SentimentIntensityAnalyzer` range from -1 to 1. (VADER: Valence Aware Dictionary and sEntiment Reasoner)
# - Scores between -1 and -0.05 general indicate negative sentiment
# - Scores between -0.05 and 0.05 are considered neutrual
# - Sores between 0.05 and 1 indicate positive sentiment
#
# The more extreme the score, the stronger the sentiment.

# %%
# import nltk sentiment intsensity analyzer module
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# download nltk VADER Lexicon data package
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/justinhoang/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# get the sentment of the texts from nltk's sentiment intensity analyzer
def get_sentiment(text):
    sia = SentimentIntensityAnalyzer()
    return sia.polarity_scores(text)['compound']

# %%
# import pandas
import pandas as pd

# %%
processed_articles_df = pd.read_csv('../DataFrames/processed_articles_df.tsv')

# %%
# fix datetime formatting
# csv does not save datetime format, rather it converts it to a string
processed_articles_df['publishedAt'] = pd.to_datetime(processed_articles_df['publishedAt'])

# %%
processed_articles_df['publishedAt'] = processed_articles_df['publishedAt'].dt.date

# %%
processed_articles_df['sentiment_title'] = processed_articles_df['processed_title'].apply(get_sentiment)
processed_articles_df['sentiment_content'] = processed_articles_df['processed_content'].apply(get_sentiment)

# %%
sentiments_df = processed_articles_df[['sentiment_title', 'sentiment_content', 'publishedAt']]

# %%
sentiments_df
# Out:
#     sentiment_title  sentiment_content publishedAt
# 0            0.0000             0.5423  2024-09-04
# 1           -0.6808             0.2263  2024-09-27
# 2            0.0000             0.5423  2024-09-30
# 3           -0.4019             0.5106  2024-09-01
# 4            0.2500             0.1779  2024-09-26
# ..              ...                ...         ...
# 94           0.2023             0.8126  2024-09-21
# 95           0.0772             0.0000  2024-09-04
# 96           0.0000            -0.4019  2024-09-04
# 97           0.3612             0.0000  2024-09-04
# 98           0.0000             0.5093  2024-09-09
#
# [99 rows x 3 columns]

# %% [markdown]
# # Stock Price Data Collection
#
# The next step in building our analysis model is collecting the stock price data for the specified company.

# %%
# import yahoo finance package
import yfinance as yf

# %%
# import timedelta modules from datetime
from datetime import timedelta

# %%
# gather stock data
def get_stock_data(ticker, start_date, end_date):
    stock = yf.Ticker(ticker)
    data = stock.history(start=start_date, end=end_date)
    return data

# %%
earliest_date = sentiments_df['publishedAt'].min()
latest_date = sentiments_df['publishedAt'].max()

# %%
start_date = earliest_date - timedelta(days=5)
end_date = latest_date + timedelta(days=5)

# %%
stock_data = get_stock_data('NVDA', start_date, end_date)

# %%
stock_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-08-27 00:00:00-04:00  125.039310  129.188949  123.869404  128.289032
# 2024-08-28 00:00:00-04:00  128.109038  128.319027  122.629511  125.599258
# 2024-08-29 00:00:00-04:00  121.349623  124.419360  116.700019  117.579941
# 2024-08-30 00:00:00-04:00  119.519777  121.739588  117.209977  119.359795
# 2024-09-03 00:00:00-04:00  116.000078  116.200058  107.280822  107.990761
# 2024-09-04 00:00:00-04:00  105.400985  113.260306  104.111095  106.200912
# 2024-09-05 00:00:00-04:00  104.981017  109.640622  104.751041  107.200829
# 2024-09-06 00:00:00-04:00  108.030759  108.140750  100.941361  102.821205
# 2024-09-09 00:00:00-04:00  104.871024  106.540887  103.681131  106.460892
# 2024-09-10 00:00:00-04:00  107.800776  109.390643  104.941020  108.090752
# 2024-09-11 00:00:00-04:00  109.380641  117.179976  107.410808  116.900002
# 2024-09-12 00:00:00-04:00  116.839996  120.790001  115.379997  119.139999
# 2024-09-13 00:00:00-04:00  119.080002  119.959999  117.599998  119.099998
# 2024-09-16 00:00:00-04:00  116.790001  118.180000  114.360001  116.779999
# 2024-09-17 00:00:00-04:00  118.169998  118.800003  114.830002  115.589996
# 2024-09-18 00:00:00-04:00  115.889999  117.699997  113.220001  113.370003
# 2024-09-19 00:00:00-04:00  117.349998  119.660004  117.250000  117.870003
# 2024-09-20 00:00:00-04:00  117.059998  118.620003  115.389999  116.000000
# 2024-09-23 00:00:00-04:00  116.550003  116.989998  114.860001  116.260002
# 2024-09-24 00:00:00-04:00  116.519997  121.800003  115.379997  120.870003
# 2024-09-25 00:00:00-04:00  122.019997  124.940002  121.610001  123.510002
# 2024-09-26 00:00:00-04:00  126.800003  127.669998  121.800003  124.040001
# 2024-09-27 00:00:00-04:00  123.970001  124.029999  119.260002  121.400002
# 2024-09-30 00:00:00-04:00  118.309998  121.500000  118.150002  121.440002
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-08-27 00:00:00-04:00  303134600       0.00           0.0
# 2024-08-28 00:00:00-04:00  448101100       0.00           0.0
# 2024-08-29 00:00:00-04:00  453023300       0.00           0.0
# 2024-08-30 00:00:00-04:00  333751600       0.00           0.0
# 2024-09-03 00:00:00-04:00  477155100       0.00           0.0
# 2024-09-04 00:00:00-04:00  372470300       0.00           0.0
# 2024-09-05 00:00:00-04:00  306850700       0.00           0.0
# 2024-09-06 00:00:00-04:00  413638100       0.00           0.0
# 2024-09-09 00:00:00-04:00  273912000       0.00           0.0
# 2024-09-10 00:00:00-04:00  268283700       0.00           0.0
# 2024-09-11 00:00:00-04:00  441422400       0.00           0.0
# 2024-09-12 00:00:00-04:00  367100500       0.01           0.0
# 2024-09-13 00:00:00-04:00  238358300       0.00           0.0
# 2024-09-16 00:00:00-04:00  248772300       0.00           0.0
# 2024-09-17 00:00:00-04:00  231925900       0.00           0.0
# 2024-09-18 00:00:00-04:00  310318900       0.00           0.0
# 2024-09-19 00:00:00-04:00  293506400       0.00           0.0
# 2024-09-20 00:00:00-04:00  382462400       0.00           0.0
# 2024-09-23 00:00:00-04:00  206228500       0.00           0.0
# 2024-09-24 00:00:00-04:00  354966800       0.00           0.0
# 2024-09-25 00:00:00-04:00  284692900       0.00           0.0
# 2024-09-26 00:00:00-04:00  302582900       0.00           0.0
# 2024-09-27 00:00:00-04:00  271009200       0.00           0.0
# 2024-09-30 00:00:00-04:00  226553700       0.00           0.0

# %% [markdown]
# **Note:**
# Some days are missing for stock price data because the Stock market is open only during the weekdays, not including holidays.
#
# We also fix the formatting for the date for the stock prices. This way we ensure that the data matches with the sentiment data.

# %%
# reformat stock data dates
stock_data.index = pd.to_datetime(stock_data.index)

# %%
stock_data.index = pd.to_datetime(stock_data.index).date

# %%
stock_data = stock_data.reset_index()

# %%
stock_data = stock_data.rename(columns={'index': 'date'})

# %%
stock_data
# Out:
#           date        Open        High         Low       Close     Volume  \
# 0   2024-08-27  125.039310  129.188949  123.869404  128.289032  303134600
# 1   2024-08-28  128.109038  128.319027  122.629511  125.599258  448101100
# 2   2024-08-29  121.349623  124.419360  116.700019  117.579941  453023300
# 3   2024-08-30  119.519777  121.739588  117.209977  119.359795  333751600
# 17  2024-09-20  117.059998  118.620003  115.389999  116.000000  382462400
# 18  2024-09-23  116.550003  116.989998  114.860001  116.260002  206228500
# 19  2024-09-24  116.519997  121.800003  115.379997  120.870003  354966800
# 20  2024-09-25  122.019997  124.940002  121.610001  123.510002  284692900
# 21  2024-09-26  126.800003  127.669998  121.800003  124.040001  302582900
# 22  2024-09-27  123.970001  124.029999  119.260002  121.400002  271009200
# 23  2024-09-30  118.309998  121.500000  118.150002  121.440002  226553700
#
#     Dividends  Stock Splits  Price Change
# 0        0.00           0.0     -0.020967
# 1        0.00           0.0     -0.063848
# 2        0.00           0.0      0.015137
# 3        0.00           0.0     -0.095250
# 4        0.00           0.0     -0.016574
# 5        0.00           0.0      0.009415
# 6        0.00           0.0     -0.040854
# 7        0.00           0.0      0.035398
# 8        0.00           0.0      0.015309
# 9        0.00           0.0      0.081499
# 10       0.00           0.0      0.019162
# 11       0.01           0.0     -0.000336
# 12       0.00           0.0     -0.019479
# 13       0.00           0.0     -0.010190
# 14       0.00           0.0     -0.019206
# 15       0.00           0.0      0.039693
# 16       0.00           0.0     -0.015865
# 17       0.00           0.0      0.002241
# 18       0.00           0.0      0.039653
# 19       0.00           0.0      0.021842
# 20       0.00           0.0      0.004291
# 21       0.00           0.0     -0.021283
# 22       0.00           0.0      0.000329
# 23       0.00           0.0           NaN

# %% [markdown]
# # Merge Data
#
# The next step is to merge the stock price data with the sentiment analysis data.
#
# Once the data is merged, we are able to create our model.

# %%
# merge the sentiment scores and stock data on their dates
merged_data_df = pd.merge(sentiments_df, stock_data, left_on='publishedAt', right_on='date', how='left')

# %%
merged_data_df = merged_data_df.sort_values('date')

# %%
merged_data_df = merged_data_df.drop('date', axis=1)

# %%
merged_data_df = merged_data_df.rename(columns={'publishedAt': 'date'})

# %%
merged_data_df
# Out:
#     sentiment_title  sentiment_content        date        Open        High  \
# 29           0.0000             0.5423  2024-09-03  116.000078  116.200058
# 40           0.0000             0.0000  2024-09-03  116.000078  116.200058
# 42           0.5423             0.5423  2024-09-03  116.000078  116.200058
# 6            0.0000             0.0516  2024-09-03  116.000078  116.200058
# 86           0.0000             0.3612  2024-09-03  116.000078  116.200058
# ..              ...                ...         ...         ...         ...
# 67          -0.5106            -0.0516  2024-09-21         NaN         NaN
# 69           0.4939             0.3612  2024-09-21         NaN         NaN
# 78          -0.0516             0.5423  2024-09-29         NaN         NaN
# 81           0.0000             0.0000  2024-09-28         NaN         NaN
# 94           0.2023             0.8126  2024-09-21         NaN         NaN
#
#            Low       Close       Volume  Dividends  Stock Splits  Price Change
# 29  107.280822  107.990761  477155100.0        0.0           0.0     -0.016574
# 40  107.280822  107.990761  477155100.0        0.0           0.0     -0.016574
# 42  107.280822  107.990761  477155100.0        0.0           0.0     -0.016574
# 6   107.280822  107.990761  477155100.0        0.0           0.0     -0.016574
# 86  107.280822  107.990761  477155100.0        0.0           0.0     -0.016574
# ..         ...         ...          ...        ...           ...           ...
# 67         NaN         NaN          NaN        NaN           NaN           NaN
# 69         NaN         NaN          NaN        NaN           NaN           NaN
# 78         NaN         NaN          NaN        NaN           NaN           NaN
# 81         NaN         NaN          NaN        NaN           NaN           NaN
# 94         NaN         NaN          NaN        NaN           NaN           NaN
#
# [99 rows x 11 columns]

# %%
import os

# %%
merged_data_df.to_csv(os.path.join('../DataFrames', 'merged_data_df.tsv'), index=False)
