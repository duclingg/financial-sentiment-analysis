# %% [markdown]
# # Sentiment Analysis
#
# From the data that we preprocessed through cleaning, then linguistic processing; we are now able to gather the sentiment of the news articles.
#
# The sentiment scores returned by `NLTK's VADER SentimentIntensityAnalyzer` range from -1 to 1. (VADER: Valence Aware Dictionary and sEntiment Reasoner)
# - Scores between -1 and -0.05 general indicate negative sentiment
# - Scores between -0.05 and 0.05 are considered neutrual
# - Sores between 0.05 and 1 indicate positive sentiment
#
# The more extreme the score, the stronger the sentiment.

# %%
# import autotokenizer and automodelforsequenceclassification modules from transformers package
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
# import pytorch package
import torch
from torch.nn.functional import softmax

# %%
model_name = "ProsusAI/finbert"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# %%
def get_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512, padding=True)
    outputs = model(**inputs)
    probabilities = softmax(outputs.logits, dim=1)
    sentiment_score = probabilities[0].tolist()
    sentiment_labels = ['negative', 'neutral', 'positive']
    sentiment = sentiment_labels[sentiment_score.index(max(sentiment_score))]
    return sentiment, max(sentiment_score)

# %%
# import pandas
import pandas as pd

# %%
cleaned_articles_df = pd.read_csv('../DataFrames/cleaned_articles_df.tsv')

# %%
cleaned_articles_df
# Out:
#                                                 title  \
# 0   DOJ subpoenas NVIDIA as part of antitrust prob...
# 1   The Leaked Nvidia RTX Has So Many Cores It Act...
# 2   ByteDance will reportedly use Huawei chips to ...
# 3   This chart shows one potential advantage AWSs ...
# 4   Nvidias days of absolute dominance in AI could...
# ..                                                ...
# 94  Nvidia is back in the trillion club and Jensen...
# 95  Sony confirms PS Pro has nextgen raytracing te...
# 96  Acers formidable new Predator Orion desktop ca...
# 97  LGs entrylevel OLED is a great gaming TV and a...
# 98  China is the first to train a single generativ...
#
#                                               content publishedAt
# 0   If you click Accept all we and our partners in...  2024-09-04
# 1   The GeForce RTX is already so big that any PC ...  2024-09-27
# 2   If you click Accept all we and our partners in...  2024-09-30
# 3   Noah BergerGetty Images Big tech cloud provide...  2024-09-26
# 4   Rodrigo Liang CEO and cofounder of SambaNova S...  2024-09-26
# ..                                                ...         ...
# 94  In This Story Nvidia NVDA chief executive Jens...  2024-09-26
# 95  When you buy through links on our articles Fut...  2024-09-13
# 96  What you need to know Acer announced two new g...  2024-09-04
# 97  If youve been curious about buying an OLED TV ...  2024-09-19
# 98  What you need to know Tech industry analyst Pa...  2024-09-30
#
# [99 rows x 3 columns]

# %%
cleaned_articles_df['publishedAt'] = pd.to_datetime(cleaned_articles_df['publishedAt'])

# %%
cleaned_articles_df['publishedAt'] = cleaned_articles_df['publishedAt'].dt.date

# %%
cleaned_articles_df
# Out:
#                                                 title  \
# 0   DOJ subpoenas NVIDIA as part of antitrust prob...
# 1   The Leaked Nvidia RTX Has So Many Cores It Act...
# 2   ByteDance will reportedly use Huawei chips to ...
# 3   This chart shows one potential advantage AWSs ...
# 4   Nvidias days of absolute dominance in AI could...
# ..                                                ...
# 94  Nvidia is back in the trillion club and Jensen...
# 95  Sony confirms PS Pro has nextgen raytracing te...
# 96  Acers formidable new Predator Orion desktop ca...
# 97  LGs entrylevel OLED is a great gaming TV and a...
# 98  China is the first to train a single generativ...
#
#                                               content publishedAt
# 0   If you click Accept all we and our partners in...  2024-09-04
# 1   The GeForce RTX is already so big that any PC ...  2024-09-27
# 2   If you click Accept all we and our partners in...  2024-09-30
# 3   Noah BergerGetty Images Big tech cloud provide...  2024-09-26
# 4   Rodrigo Liang CEO and cofounder of SambaNova S...  2024-09-26
# ..                                                ...         ...
# 94  In This Story Nvidia NVDA chief executive Jens...  2024-09-26
# 95  When you buy through links on our articles Fut...  2024-09-13
# 96  What you need to know Acer announced two new g...  2024-09-04
# 97  If youve been curious about buying an OLED TV ...  2024-09-19
# 98  What you need to know Tech industry analyst Pa...  2024-09-30
#
# [99 rows x 3 columns]

# %%
sentiment_df = pd.DataFrame()

# %%
sentiment_df['title_sentiment'], sentiment_df['title_sentiment_score'] = zip(*cleaned_articles_df['title'].apply(get_sentiment))
sentiment_df['content_sentiment'], sentiment_df['content_sentiment_score'] = zip(*cleaned_articles_df['content'].apply(get_sentiment))
sentiment_df['publishedAt'] = cleaned_articles_df['publishedAt']

# %%
sentiment_df
# Out:
#    title_sentiment  title_sentiment_score content_sentiment  \
# 0          neutral               0.909428          positive
# 1         positive               0.533817           neutral
# 2         positive               0.756288          positive
# 3         negative               0.826232          positive
# 4         negative               0.590499           neutral
# ..             ...                    ...               ...
# 94        positive               0.816141          negative
# 95        positive               0.910873          positive
# 96        positive               0.807024          positive
# 97        positive               0.797082          positive
# 98        positive               0.588012          positive
#
#     content_sentiment_score publishedAt
# 0                  0.952919  2024-09-04
# 1                  0.631737  2024-09-27
# 2                  0.952919  2024-09-30
# 3                  0.770212  2024-09-26
# 4                  0.531220  2024-09-26
# ..                      ...         ...
# 94                 0.951209  2024-09-26
# 95                 0.904911  2024-09-13
# 96                 0.884717  2024-09-04
# 97                 0.880443  2024-09-19
# 98                 0.908985  2024-09-30
#
# [99 rows x 5 columns]

# %% [markdown]
# # Stock Price Data Collection
#
# The next step in building our analysis model is collecting the stock price data for the specified company.

# %%
# import yahoo finance package
import yfinance as yf

# %%
# import timedelta modules from datetime
from datetime import timedelta

# %%
# gather stock data
def get_stock_data(ticker, start_date, end_date):
    stock = yf.Ticker(ticker)
    data = stock.history(start=start_date, end=end_date)
    return data

# %%
earliest_date = sentiment_df['publishedAt'].min()
latest_date = sentiment_df['publishedAt'].max()

# %%
start_date = earliest_date - timedelta(days=5)
end_date = latest_date + timedelta(days=5)

# %%
stock_data = get_stock_data('NVDA', start_date, end_date)

# %%
stock_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-08-30 00:00:00-04:00  119.519777  121.739588  117.209977  119.359795
# 2024-09-03 00:00:00-04:00  116.000078  116.200058  107.280822  107.990761
# 2024-09-04 00:00:00-04:00  105.400985  113.260306  104.111095  106.200912
# 2024-09-05 00:00:00-04:00  104.981017  109.640622  104.751041  107.200829
# 2024-09-06 00:00:00-04:00  108.030759  108.140750  100.941361  102.821205
# 2024-09-09 00:00:00-04:00  104.871024  106.540887  103.681131  106.460892
# 2024-09-10 00:00:00-04:00  107.800776  109.390643  104.941020  108.090752
# 2024-09-11 00:00:00-04:00  109.380641  117.179976  107.410808  116.900002
# 2024-09-12 00:00:00-04:00  116.839996  120.790001  115.379997  119.139999
# 2024-09-13 00:00:00-04:00  119.080002  119.959999  117.599998  119.099998
# 2024-09-16 00:00:00-04:00  116.790001  118.180000  114.360001  116.779999
# 2024-09-17 00:00:00-04:00  118.169998  118.800003  114.830002  115.589996
# 2024-09-18 00:00:00-04:00  115.889999  117.699997  113.220001  113.370003
# 2024-09-19 00:00:00-04:00  117.349998  119.660004  117.250000  117.870003
# 2024-09-20 00:00:00-04:00  117.059998  118.620003  115.389999  116.000000
# 2024-09-23 00:00:00-04:00  116.550003  116.989998  114.860001  116.260002
# 2024-09-24 00:00:00-04:00  116.519997  121.800003  115.379997  120.870003
# 2024-09-25 00:00:00-04:00  122.019997  124.940002  121.610001  123.510002
# 2024-09-26 00:00:00-04:00  126.800003  127.669998  121.800003  124.040001
# 2024-09-27 00:00:00-04:00  123.970001  124.029999  119.260002  121.400002
# 2024-09-30 00:00:00-04:00  118.309998  121.500000  118.150002  121.440002
# 2024-10-01 00:00:00-04:00  121.769997  122.440002  115.790001  117.000000
# 2024-10-02 00:00:00-04:00  116.440002  119.379997  115.139999  118.849998
# 2024-10-03 00:00:00-04:00  120.919998  124.360001  120.339996  122.849998
# 2024-10-04 00:00:00-04:00  124.940002  125.040001  121.830002  124.919998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-08-30 00:00:00-04:00  333751600       0.00           0.0
# 2024-09-03 00:00:00-04:00  477155100       0.00           0.0
# 2024-09-04 00:00:00-04:00  372470300       0.00           0.0
# 2024-09-05 00:00:00-04:00  306850700       0.00           0.0
# 2024-09-06 00:00:00-04:00  413638100       0.00           0.0
# 2024-09-09 00:00:00-04:00  273912000       0.00           0.0
# 2024-09-10 00:00:00-04:00  268283700       0.00           0.0
# 2024-09-11 00:00:00-04:00  441422400       0.00           0.0
# 2024-09-12 00:00:00-04:00  367100500       0.01           0.0
# 2024-09-13 00:00:00-04:00  238358300       0.00           0.0
# 2024-09-16 00:00:00-04:00  248772300       0.00           0.0
# 2024-09-17 00:00:00-04:00  231925900       0.00           0.0
# 2024-09-18 00:00:00-04:00  310318900       0.00           0.0
# 2024-09-19 00:00:00-04:00  293506400       0.00           0.0
# 2024-09-20 00:00:00-04:00  382462400       0.00           0.0
# 2024-09-23 00:00:00-04:00  206228500       0.00           0.0
# 2024-09-24 00:00:00-04:00  354966800       0.00           0.0
# 2024-09-25 00:00:00-04:00  284692900       0.00           0.0
# 2024-09-26 00:00:00-04:00  302582900       0.00           0.0
# 2024-09-27 00:00:00-04:00  271009200       0.00           0.0
# 2024-09-30 00:00:00-04:00  226553700       0.00           0.0
# 2024-10-01 00:00:00-04:00  302094500       0.00           0.0
# 2024-10-02 00:00:00-04:00  221845900       0.00           0.0
# 2024-10-03 00:00:00-04:00  277118000       0.00           0.0
# 2024-10-04 00:00:00-04:00  243678100       0.00           0.0

# %% [markdown]
# **Note:**
# Some days are missing for stock price data because the Stock market is open only during the weekdays, not including holidays.
#
# We also fix the formatting for the date for the stock prices. This way we ensure that the data matches with the sentiment data.

# %%
# reformat stock data dates
stock_data.index = pd.to_datetime(stock_data.index)

# %%
stock_data.index = pd.to_datetime(stock_data.index).date

# %%
stock_data = stock_data.reset_index()

# %%
stock_data = stock_data.rename(columns={'index': 'date'})

# %%
stock_data
# Out:
#           date        Open        High         Low       Close     Volume  \
# 0   2024-08-30  119.519777  121.739588  117.209977  119.359795  333751600
# 1   2024-09-03  116.000078  116.200058  107.280822  107.990761  477155100
# 2   2024-09-04  105.400985  113.260306  104.111095  106.200912  372470300
# 3   2024-09-05  104.981017  109.640622  104.751041  107.200829  306850700
# 4   2024-09-06  108.030759  108.140750  100.941361  102.821205  413638100
# 5   2024-09-09  104.871024  106.540887  103.681131  106.460892  273912000
# 6   2024-09-10  107.800776  109.390643  104.941020  108.090752  268283700
# 7   2024-09-11  109.380641  117.179976  107.410808  116.900002  441422400
# 8   2024-09-12  116.839996  120.790001  115.379997  119.139999  367100500
# 9   2024-09-13  119.080002  119.959999  117.599998  119.099998  238358300
# 10  2024-09-16  116.790001  118.180000  114.360001  116.779999  248772300
# 11  2024-09-17  118.169998  118.800003  114.830002  115.589996  231925900
# 12  2024-09-18  115.889999  117.699997  113.220001  113.370003  310318900
# 13  2024-09-19  117.349998  119.660004  117.250000  117.870003  293506400
# 14  2024-09-20  117.059998  118.620003  115.389999  116.000000  382462400
# 15  2024-09-23  116.550003  116.989998  114.860001  116.260002  206228500
# 16  2024-09-24  116.519997  121.800003  115.379997  120.870003  354966800
# 17  2024-09-25  122.019997  124.940002  121.610001  123.510002  284692900
# 18  2024-09-26  126.800003  127.669998  121.800003  124.040001  302582900
# 19  2024-09-27  123.970001  124.029999  119.260002  121.400002  271009200
# 20  2024-09-30  118.309998  121.500000  118.150002  121.440002  226553700
# 21  2024-10-01  121.769997  122.440002  115.790001  117.000000  302094500
# 22  2024-10-02  116.440002  119.379997  115.139999  118.849998  221845900
# 23  2024-10-03  120.919998  124.360001  120.339996  122.849998  277118000
# 24  2024-10-04  124.940002  125.040001  121.830002  124.919998  243678100
#
#     Dividends  Stock Splits
# 0        0.00           0.0
# 1        0.00           0.0
# 2        0.00           0.0
# 3        0.00           0.0
# 4        0.00           0.0
# 5        0.00           0.0
# 6        0.00           0.0
# 7        0.00           0.0
# 8        0.01           0.0
# 9        0.00           0.0
# 10       0.00           0.0
# 11       0.00           0.0
# 12       0.00           0.0
# 13       0.00           0.0
# 14       0.00           0.0
# 15       0.00           0.0
# 16       0.00           0.0
# 17       0.00           0.0
# 18       0.00           0.0
# 19       0.00           0.0
# 20       0.00           0.0
# 21       0.00           0.0
# 22       0.00           0.0
# 23       0.00           0.0
# 24       0.00           0.0

# %% [markdown]
# #### Price Change
#
# We need to create a new column in our `stock_data` table that calculates the price change of the stock from the next day.

# %%
stock_data['price_change'] = stock_data['Close'].pct_change(fill_method=None).shift(-1)

# %%
stock_data
# Out:
#           date        Open        High         Low       Close     Volume  \
# 0   2024-08-30  119.519777  121.739588  117.209977  119.359795  333751600
# 1   2024-09-03  116.000078  116.200058  107.280822  107.990761  477155100
# 2   2024-09-04  105.400985  113.260306  104.111095  106.200912  372470300
# 3   2024-09-05  104.981017  109.640622  104.751041  107.200829  306850700
# 4   2024-09-06  108.030759  108.140750  100.941361  102.821205  413638100
# 5   2024-09-09  104.871024  106.540887  103.681131  106.460892  273912000
# 6   2024-09-10  107.800776  109.390643  104.941020  108.090752  268283700
# 7   2024-09-11  109.380641  117.179976  107.410808  116.900002  441422400
# 8   2024-09-12  116.839996  120.790001  115.379997  119.139999  367100500
# 9   2024-09-13  119.080002  119.959999  117.599998  119.099998  238358300
# 10  2024-09-16  116.790001  118.180000  114.360001  116.779999  248772300
# 11  2024-09-17  118.169998  118.800003  114.830002  115.589996  231925900
# 12  2024-09-18  115.889999  117.699997  113.220001  113.370003  310318900
# 13  2024-09-19  117.349998  119.660004  117.250000  117.870003  293506400
# 14  2024-09-20  117.059998  118.620003  115.389999  116.000000  382462400
# 15  2024-09-23  116.550003  116.989998  114.860001  116.260002  206228500
# 16  2024-09-24  116.519997  121.800003  115.379997  120.870003  354966800
# 17  2024-09-25  122.019997  124.940002  121.610001  123.510002  284692900
# 18  2024-09-26  126.800003  127.669998  121.800003  124.040001  302582900
# 19  2024-09-27  123.970001  124.029999  119.260002  121.400002  271009200
# 20  2024-09-30  118.309998  121.500000  118.150002  121.440002  226553700
# 21  2024-10-01  121.769997  122.440002  115.790001  117.000000  302094500
# 22  2024-10-02  116.440002  119.379997  115.139999  118.849998  221845900
# 23  2024-10-03  120.919998  124.360001  120.339996  122.849998  277118000
# 24  2024-10-04  124.940002  125.040001  121.830002  124.919998  243678100
#
#     Dividends  Stock Splits  price_change
# 0        0.00           0.0     -0.095250
# 1        0.00           0.0     -0.016574
# 2        0.00           0.0      0.009415
# 3        0.00           0.0     -0.040854
# 4        0.00           0.0      0.035398
# 5        0.00           0.0      0.015309
# 6        0.00           0.0      0.081499
# 7        0.00           0.0      0.019162
# 8        0.01           0.0     -0.000336
# 9        0.00           0.0     -0.019479
# 10       0.00           0.0     -0.010190
# 11       0.00           0.0     -0.019206
# 12       0.00           0.0      0.039693
# 13       0.00           0.0     -0.015865
# 14       0.00           0.0      0.002241
# 15       0.00           0.0      0.039653
# 16       0.00           0.0      0.021842
# 17       0.00           0.0      0.004291
# 18       0.00           0.0     -0.021283
# 19       0.00           0.0      0.000329
# 20       0.00           0.0     -0.036561
# 21       0.00           0.0      0.015812
# 22       0.00           0.0      0.033656
# 23       0.00           0.0      0.016850
# 24       0.00           0.0           NaN

# %% [markdown]
# # Merge Data
#
# The next step is to merge the stock price data with the sentiment analysis data.
#
# Once the data is merged, we are able to create our model.

# %%
# merge the sentiment scores and stock data on their dates
merged_data_df = pd.merge(sentiment_df, stock_data, left_on='publishedAt', right_on='date', how='left')

# %%
merged_data_df = merged_data_df.sort_values('date')

# %%
merged_data_df = merged_data_df.drop('date', axis=1)

# %%
merged_data_df = merged_data_df.rename(columns={'publishedAt': 'date'})

# %%
merged_data_df
# Out:
#    title_sentiment  title_sentiment_score content_sentiment  \
# 0          neutral               0.909428          positive
# 96        positive               0.807024          positive
# 64         neutral               0.907637          negative
# 76         neutral               0.963091          positive
# 90        positive               0.861416          positive
# ..             ...                    ...               ...
# 61         neutral               0.910408           neutral
# 63        positive               0.923365          positive
# 72        negative               0.625904          positive
# 75        positive               0.898789          positive
# 87        positive               0.899882          negative
#
#     content_sentiment_score        date        Open        High         Low  \
# 0                  0.952919  2024-09-04  105.400985  113.260306  104.111095
# 96                 0.884717  2024-09-04  105.400985  113.260306  104.111095
# 64                 0.619797  2024-09-04  105.400985  113.260306  104.111095
# 76                 0.896472  2024-09-04  105.400985  113.260306  104.111095
# 90                 0.935935  2024-09-04  105.400985  113.260306  104.111095
# ..                      ...         ...         ...         ...         ...
# 61                 0.950407  2024-09-21         NaN         NaN         NaN
# 63                 0.923918  2024-09-21         NaN         NaN         NaN
# 72                 0.952919  2024-09-29         NaN         NaN         NaN
# 75                 0.924873  2024-09-28         NaN         NaN         NaN
# 87                 0.714978  2024-09-21         NaN         NaN         NaN
#
#          Close       Volume  Dividends  Stock Splits  price_change
# 0   106.200912  372470300.0        0.0           0.0      0.009415
# 96  106.200912  372470300.0        0.0           0.0      0.009415
# 64  106.200912  372470300.0        0.0           0.0      0.009415
# 76  106.200912  372470300.0        0.0           0.0      0.009415
# 90  106.200912  372470300.0        0.0           0.0      0.009415
# ..         ...          ...        ...           ...           ...
# 61         NaN          NaN        NaN           NaN           NaN
# 63         NaN          NaN        NaN           NaN           NaN
# 72         NaN          NaN        NaN           NaN           NaN
# 75         NaN          NaN        NaN           NaN           NaN
# 87         NaN          NaN        NaN           NaN           NaN
#
# [99 rows x 13 columns]

# %%
import os

# %%
merged_data_df.to_csv(os.path.join('../DataFrames', 'merged_data_df.tsv'), index=False)
